# %%
# data wrangling
import pandas as pd

# plotting
import matplotlib.pyplot as plt

# other
import time

# sklearn
from sklearn.model_selection import train_test_split

# local files
from sofascores import compute_sofa

# %%
DATA_FILEPATH = "all_hourly_data.h5"

patients = pd.read_hdf(DATA_FILEPATH, "patients")
vitals_labs = pd.read_hdf(DATA_FILEPATH, "vitals_labs")
vitals_labs_mean = pd.read_hdf(DATA_FILEPATH, "vitals_labs_mean")
interventions = pd.read_hdf(DATA_FILEPATH, "interventions")

# %%
print(patients.columns)
print(interventions.columns)
# Out:
# Index(['gender', 'ethnicity', 'age', 'insurance', 'admittime',
#        'diagnosis_at_admission', 'dischtime', 'discharge_location',
#        'fullcode_first', 'dnr_first', 'fullcode', 'dnr', 'dnr_first_charttime',
#        'cmo_first', 'cmo_last', 'cmo', 'deathtime', 'intime', 'outtime',
#        'los_icu', 'admission_type', 'first_careunit', 'mort_icu', 'mort_hosp',
#        'hospital_expire_flag', 'hospstay_seq', 'readmission_30', 'max_hours'],
#       dtype='object')
# Index(['vent', 'vaso', 'adenosine', 'dobutamine', 'dopamine', 'epinephrine',
#        'isuprel', 'milrinone', 'norepinephrine', 'phenylephrine',
#        'vasopressin', 'colloid_bolus', 'crystalloid_bolus', 'nivdurations'],
#       dtype='object')

# %%
for column in vitals_labs.columns:
    print(column)
print()
print(vitals_labs.shape)
# Out:
# ('alanine aminotransferase', 'count')
# ('alanine aminotransferase', 'mean')
# ('alanine aminotransferase', 'std')
# ('albumin', 'count')
# ('albumin', 'mean')
# ('albumin', 'std')
# ('albumin ascites', 'count')
# ('albumin ascites', 'mean')
# ('albumin ascites', 'std')
# ('albumin pleural', 'count')
# ('albumin pleural', 'mean')
# ('albumin pleural', 'std')
# ('albumin urine', 'count')
# ('albumin urine', 'mean')
# ('albumin urine', 'std')
# ('alkaline phosphate', 'count')
# ('alkaline phosphate', 'mean')
# ('alkaline phosphate', 'std')
# ('anion gap', 'count')
# ('anion gap', 'mean')
# ('anion gap', 'std')
# ('asparate aminotransferase', 'count')
# ('asparate aminotransferase', 'mean')
# ('asparate aminotransferase', 'std')
# ('basophils', 'count')
# ('basophils', 'mean')
# ('basophils', 'std')
# ('bicarbonate', 'count')
# ('bicarbonate', 'mean')
# ('bicarbonate', 'std')
# ('bilirubin', 'count')
# ('bilirubin', 'mean')
# ('bilirubin', 'std')
# ('blood urea nitrogen', 'count')
# ('blood urea nitrogen', 'mean')
# ('blood urea nitrogen', 'std')
# ('co2', 'count')
# ('co2', 'mean')
# ('co2', 'std')
# ('co2 (etco2, pco2, etc.)', 'count')
# ('co2 (etco2, pco2, etc.)', 'mean')
# ('co2 (etco2, pco2, etc.)', 'std')
# ('calcium', 'count')
# ('calcium', 'mean')
# ('calcium', 'std')
# ('calcium ionized', 'count')
# ('calcium ionized', 'mean')
# ('calcium ionized', 'std')
# ('calcium urine', 'count')
# ('calcium urine', 'mean')
# ('calcium urine', 'std')
# ('cardiac index', 'count')
# ('cardiac index', 'mean')
# ('cardiac index', 'std')
# ('cardiac output thermodilution', 'count')
# ('cardiac output thermodilution', 'mean')
# ('cardiac output thermodilution', 'std')
# ('cardiac output fick', 'count')
# ('cardiac output fick', 'mean')
# ('cardiac output fick', 'std')
# ('central venous pressure', 'count')
# ('central venous pressure', 'mean')
# ('central venous pressure', 'std')
# ('chloride', 'count')
# ('chloride', 'mean')
# ('chloride', 'std')
# ('chloride urine', 'count')
# ('chloride urine', 'mean')
# ('chloride urine', 'std')
# ('cholesterol', 'count')
# ('cholesterol', 'mean')
# ('cholesterol', 'std')
# ('cholesterol hdl', 'count')
# ('cholesterol hdl', 'mean')
# ('cholesterol hdl', 'std')
# ('cholesterol ldl', 'count')
# ('cholesterol ldl', 'mean')
# ('cholesterol ldl', 'std')
# ('creatinine', 'count')
# ('creatinine', 'mean')
# ('creatinine', 'std')
# ('creatinine ascites', 'count')
# ('creatinine ascites', 'mean')
# ('creatinine ascites', 'std')
# ('creatinine body fluid', 'count')
# ('creatinine body fluid', 'mean')
# ('creatinine body fluid', 'std')
# ('creatinine pleural', 'count')
# ('creatinine pleural', 'mean')
# ('creatinine pleural', 'std')
# ('creatinine urine', 'count')
# ('creatinine urine', 'mean')
# ('creatinine urine', 'std')
# ('diastolic blood pressure', 'count')
# ('diastolic blood pressure', 'mean')
# ('diastolic blood pressure', 'std')
# ('eosinophils', 'count')
# ('eosinophils', 'mean')
# ('eosinophils', 'std')
# ('fibrinogen', 'count')
# ('fibrinogen', 'mean')
# ('fibrinogen', 'std')
# ('fraction inspired oxygen', 'count')
# ('fraction inspired oxygen', 'mean')
# ('fraction inspired oxygen', 'std')
# ('fraction inspired oxygen set', 'count')
# ('fraction inspired oxygen set', 'mean')
# ('fraction inspired oxygen set', 'std')
# ('glascow coma scale total', 'count')
# ('glascow coma scale total', 'mean')
# ('glascow coma scale total', 'std')
# ('glucose', 'count')
# ('glucose', 'mean')
# ('glucose', 'std')
# ('heart rate', 'count')
# ('heart rate', 'mean')
# ('heart rate', 'std')
# ('height', 'count')
# ('height', 'mean')
# ('height', 'std')
# ('hematocrit', 'count')
# ('hematocrit', 'mean')
# ('hematocrit', 'std')
# ('hemoglobin', 'count')
# ('hemoglobin', 'mean')
# ('hemoglobin', 'std')
# ('lactate', 'count')
# ('lactate', 'mean')
# ('lactate', 'std')
# ('lactate dehydrogenase', 'count')
# ('lactate dehydrogenase', 'mean')
# ('lactate dehydrogenase', 'std')
# ('lactate dehydrogenase pleural', 'count')
# ('lactate dehydrogenase pleural', 'mean')
# ('lactate dehydrogenase pleural', 'std')
# ('lactic acid', 'count')
# ('lactic acid', 'mean')
# ('lactic acid', 'std')
# ('lymphocytes', 'count')
# ('lymphocytes', 'mean')
# ('lymphocytes', 'std')
# ('lymphocytes ascites', 'count')
# ('lymphocytes ascites', 'mean')
# ('lymphocytes ascites', 'std')
# ('lymphocytes atypical', 'count')
# ('lymphocytes atypical', 'mean')
# ('lymphocytes atypical', 'std')
# ('lymphocytes atypical csl', 'count')
# ('lymphocytes atypical csl', 'mean')
# ('lymphocytes atypical csl', 'std')
# ('lymphocytes body fluid', 'count')
# ('lymphocytes body fluid', 'mean')
# ('lymphocytes body fluid', 'std')
# ('lymphocytes percent', 'count')
# ('lymphocytes percent', 'mean')
# ('lymphocytes percent', 'std')
# ('lymphocytes pleural', 'count')
# ('lymphocytes pleural', 'mean')
# ('lymphocytes pleural', 'std')
# ('magnesium', 'count')
# ('magnesium', 'mean')
# ('magnesium', 'std')
# ('mean blood pressure', 'count')
# ('mean blood pressure', 'mean')
# ('mean blood pressure', 'std')
# ('mean corpuscular hemoglobin', 'count')
# ('mean corpuscular hemoglobin', 'mean')
# ('mean corpuscular hemoglobin', 'std')
# ('mean corpuscular hemoglobin concentration', 'count')
# ('mean corpuscular hemoglobin concentration', 'mean')
# ('mean corpuscular hemoglobin concentration', 'std')
# ('mean corpuscular volume', 'count')
# ('mean corpuscular volume', 'mean')
# ('mean corpuscular volume', 'std')
# ('monocytes', 'count')
# ('monocytes', 'mean')
# ('monocytes', 'std')
# ('monocytes csl', 'count')
# ('monocytes csl', 'mean')
# ('monocytes csl', 'std')
# ('neutrophils', 'count')
# ('neutrophils', 'mean')
# ('neutrophils', 'std')
# ('oxygen saturation', 'count')
# ('oxygen saturation', 'mean')
# ('oxygen saturation', 'std')
# ('partial pressure of carbon dioxide', 'count')
# ('partial pressure of carbon dioxide', 'mean')
# ('partial pressure of carbon dioxide', 'std')
# ('partial pressure of oxygen', 'count')
# ('partial pressure of oxygen', 'mean')
# ('partial pressure of oxygen', 'std')
# ('partial thromboplastin time', 'count')
# ('partial thromboplastin time', 'mean')
# ('partial thromboplastin time', 'std')
# ('peak inspiratory pressure', 'count')
# ('peak inspiratory pressure', 'mean')
# ('peak inspiratory pressure', 'std')
# ('phosphate', 'count')
# ('phosphate', 'mean')
# ('phosphate', 'std')
# ('phosphorous', 'count')
# ('phosphorous', 'mean')
# ('phosphorous', 'std')
# ('plateau pressure', 'count')
# ('plateau pressure', 'mean')
# ('plateau pressure', 'std')
# ('platelets', 'count')
# ('platelets', 'mean')
# ('platelets', 'std')
# ('positive end-expiratory pressure', 'count')
# ('positive end-expiratory pressure', 'mean')
# ('positive end-expiratory pressure', 'std')
# ('positive end-expiratory pressure set', 'count')
# ('positive end-expiratory pressure set', 'mean')
# ('positive end-expiratory pressure set', 'std')
# ('post void residual', 'count')
# ('post void residual', 'mean')
# ('post void residual', 'std')
# ('potassium', 'count')
# ('potassium', 'mean')
# ('potassium', 'std')
# ('potassium serum', 'count')
# ('potassium serum', 'mean')
# ('potassium serum', 'std')
# ('prothrombin time inr', 'count')
# ('prothrombin time inr', 'mean')
# ('prothrombin time inr', 'std')
# ('prothrombin time pt', 'count')
# ('prothrombin time pt', 'mean')
# ('prothrombin time pt', 'std')
# ('pulmonary artery pressure mean', 'count')
# ('pulmonary artery pressure mean', 'mean')
# ('pulmonary artery pressure mean', 'std')
# ('pulmonary artery pressure systolic', 'count')
# ('pulmonary artery pressure systolic', 'mean')
# ('pulmonary artery pressure systolic', 'std')
# ('pulmonary capillary wedge pressure', 'count')
# ('pulmonary capillary wedge pressure', 'mean')
# ('pulmonary capillary wedge pressure', 'std')
# ('red blood cell count', 'count')
# ('red blood cell count', 'mean')
# ('red blood cell count', 'std')
# ('red blood cell count csf', 'count')
# ('red blood cell count csf', 'mean')
# ('red blood cell count csf', 'std')
# ('red blood cell count ascites', 'count')
# ('red blood cell count ascites', 'mean')
# ('red blood cell count ascites', 'std')
# ('red blood cell count pleural', 'count')
# ('red blood cell count pleural', 'mean')
# ('red blood cell count pleural', 'std')
# ('red blood cell count urine', 'count')
# ('red blood cell count urine', 'mean')
# ('red blood cell count urine', 'std')
# ('respiratory rate', 'count')
# ('respiratory rate', 'mean')
# ('respiratory rate', 'std')
# ('respiratory rate set', 'count')
# ('respiratory rate set', 'mean')
# ('respiratory rate set', 'std')
# ('sodium', 'count')
# ('sodium', 'mean')
# ('sodium', 'std')
# ('systemic vascular resistance', 'count')
# ('systemic vascular resistance', 'mean')
# ('systemic vascular resistance', 'std')
# ('systolic blood pressure', 'count')
# ('systolic blood pressure', 'mean')
# ('systolic blood pressure', 'std')
# ('temperature', 'count')
# ('temperature', 'mean')
# ('temperature', 'std')
# ('tidal volume observed', 'count')
# ('tidal volume observed', 'mean')
# ('tidal volume observed', 'std')
# ('tidal volume set', 'count')
# ('tidal volume set', 'mean')
# ('tidal volume set', 'std')
# ('tidal volume spontaneous', 'count')
# ('tidal volume spontaneous', 'mean')
# ('tidal volume spontaneous', 'std')
# ('total protein', 'count')
# ('total protein', 'mean')
# ('total protein', 'std')
# ('total protein urine', 'count')
# ('total protein urine', 'mean')
# ('total protein urine', 'std')
# ('troponin-i', 'count')
# ('troponin-i', 'mean')
# ('troponin-i', 'std')
# ('troponin-t', 'count')
# ('troponin-t', 'mean')
# ('troponin-t', 'std')
# ('venous pvo2', 'count')
# ('venous pvo2', 'mean')
# ('venous pvo2', 'std')
# ('weight', 'count')
# ('weight', 'mean')
# ('weight', 'std')
# ('white blood cell count', 'count')
# ('white blood cell count', 'mean')
# ('white blood cell count', 'std')
# ('white blood cell count urine', 'count')
# ('white blood cell count urine', 'mean')
# ('white blood cell count urine', 'std')
# ('ph', 'count')
# ('ph', 'mean')
# ('ph', 'std')
# ('ph urine', 'count')
# ('ph urine', 'mean')
# ('ph urine', 'std')
#
# (2200954, 312)

# %%
for column in vitals_labs_mean.columns:
    print(column)
print()
print(vitals_labs_mean.shape)
# Out:
# ('alanine aminotransferase', 'mean')
# ('albumin', 'mean')
# ('albumin ascites', 'mean')
# ('albumin pleural', 'mean')
# ('albumin urine', 'mean')
# ('alkaline phosphate', 'mean')
# ('anion gap', 'mean')
# ('asparate aminotransferase', 'mean')
# ('basophils', 'mean')
# ('bicarbonate', 'mean')
# ('bilirubin', 'mean')
# ('blood urea nitrogen', 'mean')
# ('co2', 'mean')
# ('co2 (etco2, pco2, etc.)', 'mean')
# ('calcium', 'mean')
# ('calcium ionized', 'mean')
# ('calcium urine', 'mean')
# ('cardiac index', 'mean')
# ('cardiac output thermodilution', 'mean')
# ('cardiac output fick', 'mean')
# ('central venous pressure', 'mean')
# ('chloride', 'mean')
# ('chloride urine', 'mean')
# ('cholesterol', 'mean')
# ('cholesterol hdl', 'mean')
# ('cholesterol ldl', 'mean')
# ('creatinine', 'mean')
# ('creatinine ascites', 'mean')
# ('creatinine body fluid', 'mean')
# ('creatinine pleural', 'mean')
# ('creatinine urine', 'mean')
# ('diastolic blood pressure', 'mean')
# ('eosinophils', 'mean')
# ('fibrinogen', 'mean')
# ('fraction inspired oxygen', 'mean')
# ('fraction inspired oxygen set', 'mean')
# ('glascow coma scale total', 'mean')
# ('glucose', 'mean')
# ('heart rate', 'mean')
# ('height', 'mean')
# ('hematocrit', 'mean')
# ('hemoglobin', 'mean')
# ('lactate', 'mean')
# ('lactate dehydrogenase', 'mean')
# ('lactate dehydrogenase pleural', 'mean')
# ('lactic acid', 'mean')
# ('lymphocytes', 'mean')
# ('lymphocytes ascites', 'mean')
# ('lymphocytes atypical', 'mean')
# ('lymphocytes atypical csl', 'mean')
# ('lymphocytes body fluid', 'mean')
# ('lymphocytes percent', 'mean')
# ('lymphocytes pleural', 'mean')
# ('magnesium', 'mean')
# ('mean blood pressure', 'mean')
# ('mean corpuscular hemoglobin', 'mean')
# ('mean corpuscular hemoglobin concentration', 'mean')
# ('mean corpuscular volume', 'mean')
# ('monocytes', 'mean')
# ('monocytes csl', 'mean')
# ('neutrophils', 'mean')
# ('oxygen saturation', 'mean')
# ('partial pressure of carbon dioxide', 'mean')
# ('partial pressure of oxygen', 'mean')
# ('partial thromboplastin time', 'mean')
# ('peak inspiratory pressure', 'mean')
# ('phosphate', 'mean')
# ('phosphorous', 'mean')
# ('plateau pressure', 'mean')
# ('platelets', 'mean')
# ('positive end-expiratory pressure', 'mean')
# ('positive end-expiratory pressure set', 'mean')
# ('post void residual', 'mean')
# ('potassium', 'mean')
# ('potassium serum', 'mean')
# ('prothrombin time inr', 'mean')
# ('prothrombin time pt', 'mean')
# ('pulmonary artery pressure mean', 'mean')
# ('pulmonary artery pressure systolic', 'mean')
# ('pulmonary capillary wedge pressure', 'mean')
# ('red blood cell count', 'mean')
# ('red blood cell count csf', 'mean')
# ('red blood cell count ascites', 'mean')
# ('red blood cell count pleural', 'mean')
# ('red blood cell count urine', 'mean')
# ('respiratory rate', 'mean')
# ('respiratory rate set', 'mean')
# ('sodium', 'mean')
# ('systemic vascular resistance', 'mean')
# ('systolic blood pressure', 'mean')
# ('temperature', 'mean')
# ('tidal volume observed', 'mean')
# ('tidal volume set', 'mean')
# ('tidal volume spontaneous', 'mean')
# ('total protein', 'mean')
# ('total protein urine', 'mean')
# ('troponin-i', 'mean')
# ('troponin-t', 'mean')
# ('venous pvo2', 'mean')
# ('weight', 'mean')
# ('white blood cell count', 'mean')
# ('white blood cell count urine', 'mean')
# ('ph', 'mean')
# ('ph urine', 'mean')
#
# (2200954, 104)
